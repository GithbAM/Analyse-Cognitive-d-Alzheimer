# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
# Chargement du modèle

# Chargement du modèle

@st.cache_resource
def load_pipeline():
    src_dir = Path(__file__).resolve().parent
    model_path = src_dir.parent / "models" / "alzheimer_pipeline_trained.pkl"
    return joblib.load(model_path)

pipeline = load_pipeline()
# Out:
# 2025-09-05 18:41:00.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 18:41:00.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 18:41:00.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 18:41:00.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 18:41:00.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 18:41:00.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 18:41:00.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Prédictions

def predict_alzheimer_risk(inputs: dict):
    """Prédit le risque d'Alzheimer à partir du modèle"""

    df = pd.DataFrame([inputs])
    pred, proba = pipeline.predict_new_data(df)
    probability = proba[0, 1]

    if probability > 0.7:
        risk_level = 'Élevé'
        recommendation = 'Bilan neuropsychologique approfondi recommandé dans les 15 jours'
        color = "red"

    elif probability > 0.4:
        risk_level = 'Modéré'
        recommendation = 'Suivi rapproché et réévaluation dans 3 mois'
        color = 'orange'

    else:
        risk_level = 'Faible'
        recommendation = 'Suivi de routine, réévaluation annuelle'
        color = 'green'

    return {'probability': float(probability),
           'risk_level': risk_level,
           'recommendation': recommendation,
           'color': color}

# %%
# Configuration de la page

st.set_page_config(page_title='Clinical Decision Support',
                  layout='wide')
st.title("Clinical Decision Support System")
st.subheader("Aide au diagnostic précoce de la maladie d'Alzheimer")

st.sidebar.header("Données Patient")

#Évaluations Cognitives
st.sidebar.markdown("Évaluations Cognitives")
mmse = st.sidebar.slider("Score MMSE (0-30)", 0, 30, 20)
functional_assessment = st.sidebar.slider("Score Fonctionnel (0-10)", 0.0, 10.0, 7.5, 0.1)
adl = st.sidebar.slider("Score ADL (0-10)", 0.0, 10.0, 8.2, 0.1)

#Symptomes Cognitifs
st.sidebar.markdown("Symptômes Cognitifs")
memory_complaints = st.sidebar.checkbox("Troubles mémoriels")
behavioral_problems = st.sidebar.checkbox("Troubles comportementaux")
confusion = st.sidebar.checkbox("Confusion")
disorientation = st.sidebar.checkbox("Désorientation") 
personality_changes = st.sidebar.checkbox("Changements de personnalité")
difficulty_completing_tasks = st.sidebar.checkbox("Difficultés à effectuer des tâches complexes")
forgetfulness = st.sidebar.checkbox("Oublis fréquents")

#Données Démographiques
st.sidebar.markdown("Données Démographiques")
age = st.sidebar.slider("Âge", 50, 100, 65)
gender = st.sidebar.selectbox("Genre", options=[0, 1], index=1, help="0=Femme, 1=Homme")
ethnicity = st.sidebar.selectbox("Origine ethnique", options=[0, 1, 2, 3], index=0, help="Origine ethnique (0-3)")
education_level = st.sidebar.selectbox("Niveau d'éducation", options=[0, 1, 2, 3, 4], index=2, help="Niveau d'éducation (0-4)")

# Paramètres Physiologiques
st.sidebar.markdown("Paramètres Physiologiques")
bmi = st.sidebar.slider("IMC (15-40)", 15.0, 40.0, 25.0, 0.1)
systolic_bp = st.sidebar.slider("TA Systolique (90-200)", 90, 200, 130)
diastolic_bp = st.sidebar.slider("TA Diastolique (50-120)", 50, 120, 80)
cholesterol_total = st.sidebar.slider("Cholestérol total (100-400)", 100, 400, 200)
cholesterol_ldl = st.sidebar.slider("LDL (50-250)", 50, 250, 120)
cholesterol_hdl = st.sidebar.slider("HDL (20-100)", 20, 100, 50)
cholesterol_triglycerides = st.sidebar.slider("Triglycérides (50-400)")

# Mode de Vie
st.sidebar.markdown("Mode de Vie")
diet_quality = st.sidebar.slider("Qualité de l'alimentation (0-10)", 0, 10, 7)
physical_activity = st.sidebar.slider("Activité physique (h/semaine, 0-10)", 0, 10, 4)
alcohol_consumption = st.sidebar.slider("Consommation d'alcool (verres/semaine, 0-10)", 0, 10, 2)
sleep_quality = st.sidebar.slider("Qualité du sommeil (0-10)", 0, 10, 7)
smoking = st.sidebar.checkbox("Tabagisme actuel")

# Antécédents Médicaux
st.sidebar.markdown("Antécédents Médicaux")
family_history_alzheimers = st.sidebar.checkbox("Antécédents familiaux d'Alzheimer")
cardiovascular_disease = st.sidebar.checkbox("Maladie cardiovasculaire")
diabetes = st.sidebar.checkbox("Diabète")
depression = st.sidebar.checkbox("Dépression")
head_injury = st.sidebar.checkbox("Traumatisme crânien")
hypertension = st.sidebar.checkbox("Hypertension artérielle")

# Bouton
analyze_button = st.sidebar.button("Analyser le Risque", type="primary")
# Out:
# 2025-09-05 19:45:30.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.797 Session state does not function when running a script without `streamlit run`
# 2025-09-05 19:45:30.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:45:30.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Layout

col1, col2 = st.columns([2, 1])

if analyze_button:
    inputs = {
        'Age': age,
        'Gender': gender,
        'Ethnicity': ethnicity,
        'EducationLevel': education_level,
        'BMI': bmi,
        'Smoking': int(smoking),
        'AlcoholConsumption': alcohol_consumption,
        'PhysicalActivity': physical_activity,
        'DietQuality': diet_quality,
        'SleepQuality': sleep_quality,
        'FamilyHistoryAlzheimers': int(family_history_alzheimers),
        'CardiovascularDisease': int(cardiovascular_disease),
        'Diabetes': int(diabetes),
        'Depression': int(depression),
        'HeadInjury': int(head_injury),
        'Hypertension': int(hypertension),
        'SystolicBP': systolic_bp,
        'DiastolicBP': diastolic_bp,
        'CholesterolTotal': cholesterol_total,
        'CholesterolLDL': cholesterol_ldl,
        'CholesterolHDL': cholesterol_hdl,
        'CholesterolTriglycerides': cholesterol_triglycerides,
        'MMSE': mmse,
        'FunctionalAssessment': functional_assessment,
        'MemoryComplaints': int(memory_complaints),
        'BehavioralProblems': int(behavioral_problems),
        'ADL': adl,
        'Confusion': int(confusion),
        'Disorientation': int(disorientation),
        'PersonalityChanges': int(personality_changes),
        'DifficultyCompletingTasks': int(difficulty_completing_tasks),
        'Forgetfulness': int(forgetfulness)
    }

    result = predict_alzheimer_risk(inputs)

    with col1:
        st.markdown("Résultat de l'Analyse")
        st.metric(
            label="Probabilité de Risque Alzheimer",
            value=f"{result['probability']:.1%}",
            delta=f"Risque {result['risk_level']}"
        )

        if result['color'] == 'red':
            st.error(result['recommendation'])
        elif result['color'] == 'orange':
            st.warning(result['recommendation'])
        else:
            st.success(result['recommendation'])

        risk_data = pd.DataFrame({
            'Niveau': ['Faible', 'Modéré', 'Élevé'],
            'Seuil': [0.4, 0.7, 1.0],
            'Couleur': ['green', 'orange', 'red']
        })

        fig = px.bar(
            risk_data,
            x='Niveau',
            y='Seuil',
            color='Couleur',
            color_discrete_map={'green': '#22c55e', 'orange': '#f97316', 'red': '#ef4444'},
            title="Échelle de Risque"
        )
        fig.add_hline(y=result['probability'], line_dash="dash", line_color="blue",
                      annotation_text=f"Patient: {result['probability']:.1%}")
        st.plotly_chart(fig, use_container_width=True)

    with col2:
            st.markdown("## 📋 Analyse des Features")
            
            # Features principales utilisées (les 17 sélectionnées)
            st.markdown("### 🎯 Features Actives (17 sélectionnées)")
            key_features = [
                ("FunctionalAssessment", functional_assessment, "8-10", "Impact maximum"),
                ("MMSE", mmse, "24-30", "Cognition"),
                ("ADL", adl, "8-10", "Autonomie"),
                ("MemoryComplaints", "Oui" if memory_complaints else "Non", "-", "Plaintes"),
                ("BehavioralProblems", "Oui" if behavioral_problems else "Non", "-", "Comportement")
            ]
            
            for feature, value, normal, description in key_features:
                if feature == "MMSE" and value < 24:
                    st.markdown(f"🔴 **{feature}**: {value} (Normal: {normal}) - {description}")
                elif feature == "FunctionalAssessment" and value < 8:
                    st.markdown(f"🔴 **{feature}**: {value} (Normal: {normal}) - {description}")
                elif feature == "ADL" and value < 8:
                    st.markdown(f"🟡 **{feature}**: {value} (Normal: {normal}) - {description}")
                elif feature in ["MemoryComplaints", "BehavioralProblems"] and value == "Oui":
                    st.markdown(f"🔴 **{feature}**: {value} - {description}")
                else:
                    st.markdown(f"🟢 **{feature}**: {value} - {description}")
            
            # Facteurs de risque supplémentaires saisis
            st.markdown("### 🏥 Facteurs Contextuels Saisis")
            risk_factors = []
            if family_history_alzheimers:
                risk_factors.append("Antécédents familiaux")
            if cardiovascular_disease:
                risk_factors.append("Maladie cardiovasculaire")
            if diabetes:
                risk_factors.append("Diabète")
            if depression:
                risk_factors.append("Dépression")
            if hypertension:
                risk_factors.append("Hypertension")
            if smoking:
                risk_factors.append("Tabagisme")
                
            if risk_factors:
                st.markdown("🟡 **Facteurs présents**: " + ", ".join(risk_factors))
            else:
                st.markdown("🟢 **Aucun facteur de risque majeur**")

else:
    # Écran d'accueil
    with col1:
        st.markdown("## 🏥 Interface Complète - 32 Variables")
        st.markdown(f"""
        Cette version utilise **TOUTES les variables** du dataset pour 
        une évaluation exhaustive du risque Alzheimer.
        
        **🎯 Architecture Complète:**
        - 📝 **32 variables éditables**
        - 🔧 **Scaler sur 32 features**
        - 🎯 **Prédiction sur 17 features**
        - 🚀 **Le modèle réel**
        
        **📊 Variables par catégorie:**
        - 🧠 **Cognitives**: MMSE, FunctionalAssessment, ADL, symptômes
        - 👤 **Démographiques**: Âge, Genre, Éducation, Origine
        - 🏥 **Physiologiques**: BMI, TA, Cholestérol complet
        - 🏃‍♂️ **Mode de vie**: Alimentation, Sport, Sommeil, Tabac
        - 🩺 **Antécédents**: Familiaux, Cardio, Diabète, etc.
        
        **Impact clinique avec modèle complet:**
        - ✅ **91.03% précision réelle**
        - 🎯 **Évaluation exhaustive**
        - ⚡ **Pipeline production**
        - 🏥 **Interface médicale complète**
        """)
        
    with col2:
        st.markdown("## 🔬 Détails Techniques")
        st.markdown(f"""
        ### ✅ Variables Implémentées
        **Toutes les 32 features du dataset original:**
        
        **🧠 Cognitives (7)**: MMSE, FunctionalAssessment, ADL, 
        MemoryComplaints, BehavioralProblems, Confusion, etc.
        
        **🏥 Physiologiques (8)**: Age, BMI, SystolicBP, 
        DiastolicBP, Cholestérol complet
        
        **🏃‍♂️ Mode de vie (5)**: DietQuality, PhysicalActivity, 
        AlcoholConsumption, SleepQuality, Smoking
        
        **🩺 Antécédents (7)**: FamilyHistory, CardiovascularDisease, 
        Diabetes, Depression, HeadInjury, etc.
        
        **👤 Démographiques (3)**: Gender, Ethnicity, EducationLevel
        """)
        
        st.success(f"""
        **🎯 Fonctionnement Exact**  
        La pipeline fait exactement ceci:
        1. **Scaler**: 32 features → standardisation
        2. **Sélection**: 17 features optimales  
        3. **Random Forest**: Prédiction finale
        4. **Output**: Probabilité + Recommandation
        """)

st.markdown("---")
st.markdown("**Clinical Decision Support System")
# Out:
# 2025-09-05 19:47:37.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-05 19:47:37.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
